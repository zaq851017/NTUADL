# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
list_p=[-192.18094359482092,-180.8286391888048,-83.24063640749159,-49.60986570141231,-52.63682406196272,-3.8749378637459726,27.15788734684525,16.825635769324773,14.78260154851904,42.10456589087456,27.080242848197955,77.7217028506271,61.88163155852517,67.16985789991934,110.6565468248177,78.80753468642395,94.24207366572034,113.5890849925158,121.01822417214298,167.39563979405855]

# %%
epoch = []
acc_p=[]
for i in range (15):
    epoch.append(80*i+320)
for i in range(15):
    sum_t = 0.0
    for j in range(i,i+5):
        sum_t += list_p[j]
    acc_p.append(sum_t/5)

# %%
#plt.figure(figsize=(15,10),dpi=100,linewidth = 2)
plt.plot(epoch,acc_p,'s-',color = 'r', label="pg")
plt.title("pg learning curves of rewards with MA(n=5)")
plt.xlabel("epoch")
plt.ylabel("reward")
plt.show()
